# %% [markdown]
# # EDA Audit
#
# This notebook contains exploratory data analysis for the churn dataset, including data profiling, missing value checks, feature distributions, and business observations.
#
# ## Sections
# 1. Data loading
# 2. Overview statistics
# 3. Missing values and data quality checks
# 4. Distribution and segmentation analysis
# 5. Key findings and next steps
